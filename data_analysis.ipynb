# %%
import pandas as pd

df = pd.read_csv('scrubbed.csv')

df.info()

df.head()

df.isnull
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  str
#  1   city                  80332 non-null  str
#  2   state                 74535 non-null  str
#  3   country               70662 non-null  str
#  4   shape                 78400 non-null  str
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  str
#  7   comments              80317 non-null  str
#  8   date posted           80332 non-null  str
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(2), str(8)
# memory usage: 6.7+ MB
# ...

# %% [markdown]
# date is a string
# null values in state

# %%
df['city'].value_counts().head(50)
# Out:
# city
# seattle                     525
# phoenix                     454
# portland                    374
# las vegas                   368
# los angeles                 353
# san diego                   338
# houston                     297
# chicago                     265
# tucson                      241
# miami                       239
# orlando                     220
# austin                      218
# springfield                 214
# albuquerque                 213
# sacramento                  201
# columbus                    200
# san jose                    189
# london (uk/england)         189
# san francisco               187
# denver                      185
# san antonio                 175
# jacksonville                172
# toronto (canada)            172
# myrtle beach                166
# dallas                      160
# salem                       154
# charlotte                   148
# columbia                    147
# new york city (brooklyn)    147
# ...

# %%
us_df = df[df['country'] == 'us']
us_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 65114 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              65114 non-null  str
#  1   city                  65114 non-null  str
#  2   state                 65114 non-null  str
#  3   country               65114 non-null  str
#  4   shape                 63561 non-null  str
#  5   duration (seconds)    65114 non-null  object
#  6   duration (hours/min)  65114 non-null  str
#  7   comments              65101 non-null  str
#  8   date posted           65114 non-null  str
#  9   latitude              65114 non-null  object
#  10  longitude             65114 non-null  float64
# dtypes: float64(1), object(2), str(8)
# memory usage: 6.0+ MB

# %% [markdown]
# do certain shapes appear at certain times?
#
# most frequent latitude

# %%
# ['longitude'] thowing key error - used iloc to get last column
last_col_us = df[df['country'] == 'us'].iloc[:, -1]
last_col_us.describe()
# Out:
# count    65114.000000
# mean       -95.710870
# std         18.108493
# min       -176.658056
# 25%       -115.116667
# 50%        -90.065556
# 75%        -81.023056
# max        -65.831667
# Name: longitude , dtype: float64

# %%
# ['latitude'] convert from object to float64 
# get description for latitude of sightings when country is us
df['latitude'] = pd.to_numeric(df['latitude'].str.replace(',', ''), errors='coerce')
us_latitude = df[df['country'] == 'us']['latitude']
us_latitude.describe()
# Out:
# count    53205.000000
# mean        38.210703
# std          5.595109
# min         17.967778
# 25%         34.052222
# 50%         38.801944
# 75%         41.850000
# max         70.636944
# Name: latitude, dtype: float64
